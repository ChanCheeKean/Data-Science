# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np
from torch.nn import Linear

# %% [markdown]
# # Basic

# %%
X = torch.randn(100, 1)*10
# weight = 3
y = X + 3*torch.randn(100, 1)
plt.plot(X.numpy(), y.numpy(), 'o')
plt.ylabel('y')
plt.xlabel('x')

# %%
model = nn.Linear(1, 1)
# arbitary weight, without seeing the data
print(model.weight)
print(model.bias)

# %% [markdown]
# <div class="alert alert-info"><strong>NOTE:</strong> The "Linear" model layer used here doesn't really refer to linear regression. Instead, it describes the type of neural network layer employed. Linear layers are also called "fully connected" or "dense" layers. Going forward our models may contain linear layers, convolutional layers, and more.</div>

# %%
class LR(nn.Module):
    def __init__(self, input_size, output_size):
        # calling init of parent Class
        super().__init__()
        self.linear = nn.Linear(input_size, output_size)
    def forward(self, x):
        pred = self.linear(x)
        return pred

# %%
torch.manual_seed(59)
model = LR(1, 1)
# initial parameters generated by system randomly
for name, param in model.named_parameters():
    print(name, '\t', param.item())

# %%
x = torch.tensor([2.0])
print(model.forward(x))

# %% [markdown]
# which is confirmed with $f(x) = (0.1060)(2.0)+(0.9638) = 1.1758$

# %%
x1 = np.array([X.min(),X.max()])
# ax + b
[w, b] = model.parameters()
y1 = w.item() * x1 + b.item()

plt.scatter(X.numpy(), y.numpy())
plt.plot(x1, y1,'r')
plt.ylabel('y')
plt.xlabel('x');

# %% [markdown]
# The initial Model without loss function

# %% [markdown]
# # Model Training

# %%
X = torch.randn(100, 1)*10
# weight = 3
y = X + 3*torch.randn(100, 1)

# %%
class LR(nn.Module):
    def __init__(self, input_size, output_size):
        # calling init of parent Class
        super().__init__()
        self.linear = nn.Linear(input_size, output_size)
    def forward(self, x):
        pred = self.linear(x)
        return pred

# define model, loss function and optimizer
model = LR(1, 1)
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 1e-3)

# %%
# train model
epochs = 50
losses = []

for i in range(epochs):
    i+=1
    y_pred = model.forward(X) # create predictions
    loss = criterion(y_pred, y) # calculate loss
    losses.append(loss)
    
    w, b = model.parameters()
    print(f"\nepoch: {i}; loss: {loss.item()}; weight: {w.item()}; bias: {b.item()}")
    print(f"Gradient1: {w.grad}; Gradient1: {b.grad};")
    
    # Reset the stored gradient for new epoch to prevent compounding, as Gradients accumulate with every backprop. 
    optimizer.zero_grad()
    # backprop to get the derivative, gradient of w,b will change after backprop
    loss.backward()
    # update the hyperparameters of our model according to the gradient of w and b
    optimizer.step()
# Out:
# epoch: 1; loss: 9.473544120788574; weight: 0.9830675721168518; bias: -0.4375547170639038
# Gradient1: tensor([[-0.0197]]); Gradient1: tensor([-0.9804]);
# Gradient1: tensor([[-2.2071]]); Gradient1: tensor([-2.5812]);
#
# epoch: 2; loss: 9.465242385864258; weight: 0.9852746725082397; bias: -0.43497350811958313
# Gradient1: tensor([[-2.2071]]); Gradient1: tensor([-2.5812]);
# Gradient1: tensor([[-3.8043]]); Gradient1: tensor([-4.1763]);
#
# epoch: 3; loss: 9.454459190368652; weight: 0.9890789985656738; bias: -0.4307972192764282
# Gradient1: tensor([[-3.8043]]); Gradient1: tensor([-4.1763]);
# Gradient1: tensor([[-4.3842]]); Gradient1: tensor([-5.7620]);
#
# epoch: 4; loss: 9.44538688659668; weight: 0.9934632182121277; bias: -0.4250352084636688
# Gradient1: tensor([[-4.3842]]); Gradient1: tensor([-5.7620]);
# Gradient1: tensor([[-3.7916]]); Gradient1: tensor([-7.3350]);
#
# epoch: 5; loss: 9.43807601928711; weight: 0.9972547888755798; bias: -0.4177001714706421
# Gradient1: tensor([[-3.7916]]); Gradient1: tensor([-7.3350]);
# Gradient1: tensor([[-2.1842]]); Gradient1: tensor([-8.8924]);
#
# epoch: 6; loss: 9.428459167480469; weight: 0.999439001083374; bias: -0.40880778431892395
# Gradient1: tensor([[-2.1842]]); Gradient1: tensor([-8.8924]);
# Gradient1: tensor([[0.0089]]); Gradient1: tensor([-10.4314]);
#
# epoch: 7; loss: 9.412495613098145; weight: 0.9994301199913025; bias: -0.3983764052391052
# Gradient1: tensor([[0.0089]]); Gradient1: tensor([-10.4314]);
# Gradient1: tensor([[2.2024]]); Gradient1: tensor([-11.9495]);
#
# epoch: 8; loss: 9.390307426452637; weight: 0.9972277283668518; bias: -0.3864268660545349
# Gradient1: tensor([[2.2024]]); Gradient1: tensor([-11.9495]);
# Gradient1: tensor([[3.8108]]); Gradient1: tensor([-13.4443]);
#
# epoch: 9; loss: 9.36618709564209; weight: 0.9934169054031372; bias: -0.37298253178596497
# Gradient1: tensor([[3.8108]]); Gradient1: tensor([-13.4443]);
# Gradient1: tensor([[4.4049]]); Gradient1: tensor([-14.9133]);
#
# epoch: 10; loss: 9.344459533691406; weight: 0.9890120029449463; bias: -0.3580692410469055
# Gradient1: tensor([[4.4049]]); Gradient1: tensor([-14.9133]);
# Gradient1: tensor([[3.8264]]); Gradient1: tensor([-16.3536]);
#
# epoch: 11; loss: 9.325325965881348; weight: 0.9851856231689453; bias: -0.34171566367149353
# Gradient1: tensor([[3.8264]]); Gradient1: tensor([-16.3536]);
# Gradient1: tensor([[2.2301]]); Gradient1: tensor([-17.7622]);
#
# epoch: 12; loss: 9.30483627319336; weight: 0.9829554557800293; bias: -0.3239535093307495
# Gradient1: tensor([[2.2301]]); Gradient1: tensor([-17.7622]);
# Gradient1: tensor([[0.0429]]); Gradient1: tensor([-19.1358]);
#
# epoch: 13; loss: 9.279009819030762; weight: 0.982912540435791; bias: -0.30481767654418945
# Gradient1: tensor([[0.0429]]); Gradient1: tensor([-19.1358]);
# Gradient1: tensor([[-2.1507]]); Gradient1: tensor([-20.4712]);
#
# epoch: 14; loss: 9.248003959655762; weight: 0.9850631952285767; bias: -0.28434646129608154
# Gradient1: tensor([[-2.1507]]); Gradient1: tensor([-20.4712]);
# Gradient1: tensor([[-3.7644]]); Gradient1: tensor([-21.7651]);
#
# epoch: 15; loss: 9.216155052185059; weight: 0.9888275861740112; bias: -0.26258134841918945
# Gradient1: tensor([[-3.7644]]); Gradient1: tensor([-21.7651]);
# Gradient1: tensor([[-4.3668]]); Gradient1: tensor([-23.0145]);
#
# epoch: 16; loss: 9.187873840332031; weight: 0.9931944012641907; bias: -0.2395668774843216
# Gradient1: tensor([[-4.3668]]); Gradient1: tensor([-23.0145]);
# Gradient1: tensor([[-3.7967]]); Gradient1: tensor([-24.2166]);
#
# epoch: 17; loss: 9.163461685180664; weight: 0.9969911575317383; bias: -0.21535024046897888
# Gradient1: tensor([[-3.7967]]); Gradient1: tensor([-24.2166]);
# Gradient1: tensor([[-2.2061]]); Gradient1: tensor([-25.3694]);
#
# epoch: 18; loss: 9.13903522491455; weight: 0.9991973042488098; bias: -0.1899808794260025
# Gradient1: tensor([[-2.2061]]); Gradient1: tensor([-25.3694]);
# Gradient1: tensor([[-0.0195]]); Gradient1: tensor([-26.4708]);
#
# epoch: 19; loss: 9.110624313354492; weight: 0.9992167949676514; bias: -0.16351011395454407
# Gradient1: tensor([[-0.0195]]); Gradient1: tensor([-26.4708]);
# Gradient1: tensor([[2.1794]]); Gradient1: tensor([-27.5192]);
#
# epoch: 20; loss: 9.078356742858887; weight: 0.997037410736084; bias: -0.13599088788032532
# Gradient1: tensor([[2.1794]]); Gradient1: tensor([-27.5192]);
# Gradient1: tensor([[3.8034]]); Gradient1: tensor([-28.5132]);
#
# epoch: 21; loss: 9.046551704406738; weight: 0.9932339787483215; bias: -0.10747766494750977
# Gradient1: tensor([[3.8034]]); Gradient1: tensor([-28.5132]);
# Gradient1: tensor([[4.4191]]); Gradient1: tensor([-29.4512]);
#
# epoch: 22; loss: 9.019647598266602; weight: 0.9888148307800293; bias: -0.07802646607160568
# Gradient1: tensor([[4.4191]]); Gradient1: tensor([-29.4512]);
# Gradient1: tensor([[3.8622]]); Gradient1: tensor([-30.3314]);
#
# epoch: 23; loss: 8.997980117797852; weight: 0.9849525690078735; bias: -0.047695014625787735
# Gradient1: tensor([[3.8622]]); Gradient1: tensor([-30.3314]);
# Gradient1: tensor([[2.2818]]); Gradient1: tensor([-31.1521]);
#
# epoch: 24; loss: 8.977668762207031; weight: 0.982670783996582; bias: -0.0165429525077343
# Gradient1: tensor([[2.2818]]); Gradient1: tensor([-31.1521]);
# Gradient1: tensor([[0.1001]]); Gradient1: tensor([-31.9110]);
#
# epoch: 25; loss: 8.954689025878906; weight: 0.9825706481933594; bias: 0.0153680220246315
# Gradient1: tensor([[0.1001]]); Gradient1: tensor([-31.9110]);
# Gradient1: tensor([[-2.0998]]); Gradient1: tensor([-32.6061]);
#
# epoch: 26; loss: 8.929075241088867; weight: 0.9846704602241516; bias: 0.0479741171002388
# Gradient1: tensor([[-2.0998]]); Gradient1: tensor([-32.6061]);
# Gradient1: tensor([[-3.7302]]); Gradient1: tensor([-33.2354]);
#
# epoch: 27; loss: 8.905072212219238; weight: 0.9884006977081299; bias: 0.08120956271886826
# Gradient1: tensor([[-3.7302]]); Gradient1: tensor([-33.2354]);
# Gradient1: tensor([[-4.3555]]); Gradient1: tensor([-33.7973]);
#
# epoch: 28; loss: 8.887073516845703; weight: 0.992756187915802; bias: 0.11500689387321472
# Gradient1: tensor([[-4.3555]]); Gradient1: tensor([-33.7973]);
# Gradient1: tensor([[-3.8084]]); Gradient1: tensor([-34.2905]);
#
# epoch: 29; loss: 8.875394821166992; weight: 0.9965645670890808; bias: 0.14929735660552979
# Gradient1: tensor([[-3.8084]]); Gradient1: tensor([-34.2905]);
# Gradient1: tensor([[-2.2349]]); Gradient1: tensor([-34.7140]);
#
# epoch: 30; loss: 8.866100311279297; weight: 0.9987995028495789; bias: 0.18401136994361877
# Gradient1: tensor([[-2.2349]]); Gradient1: tensor([-34.7140]);
# Gradient1: tensor([[-0.0553]]); Gradient1: tensor([-35.0675]);
#
# epoch: 31; loss: 8.855053901672363; weight: 0.9988547563552856; bias: 0.2190789133310318
# Gradient1: tensor([[-0.0553]]); Gradient1: tensor([-35.0675]);
# Gradient1: tensor([[2.1484]]); Gradient1: tensor([-35.3509]);
#
# epoch: 32; loss: 8.84214973449707; weight: 0.9967063069343567; bias: 0.25442981719970703
# Gradient1: tensor([[2.1484]]); Gradient1: tensor([-35.3509]);
# Gradient1: tensor([[3.7876]]); Gradient1: tensor([-35.5642]);
#
# epoch: 33; loss: 8.831501960754395; weight: 0.9929186701774597; bias: 0.2899939715862274
# Gradient1: tensor([[3.7876]]); Gradient1: tensor([-35.5642]);
# Gradient1: tensor([[4.4246]]); Gradient1: tensor([-35.7073]);
#
# epoch: 34; loss: 8.82741928100586; weight: 0.9884940981864929; bias: 0.3257012367248535
# Gradient1: tensor([[4.4246]]); Gradient1: tensor([-35.7073]);
# Gradient1: tensor([[3.8892]]); Gradient1: tensor([-35.7802]);
#
# epoch: 35; loss: 8.830158233642578; weight: 0.9846048951148987; bias: 0.3614813983440399
# Gradient1: tensor([[3.8892]]); Gradient1: tensor([-35.7802]);
# Gradient1: tensor([[2.3245]]); Gradient1: tensor([-35.7825]);
#
# epoch: 36; loss: 8.835692405700684; weight: 0.982280433177948; bias: 0.39726391434669495
# Gradient1: tensor([[2.3245]]); Gradient1: tensor([-35.7825]);
# Gradient1: tensor([[0.1483]]); Gradient1: tensor([-35.7139]);
#
# epoch: 37; loss: 8.839739799499512; weight: 0.982132077217102; bias: 0.4329778254032135
# Gradient1: tensor([[0.1483]]); Gradient1: tensor([-35.7139]);
# Gradient1: tensor([[-2.0579]]); Gradient1: tensor([-35.5739]);
#
# epoch: 38; loss: 8.842031478881836; weight: 0.9841899871826172; bias: 0.46855175495147705
# Gradient1: tensor([[-2.0579]]); Gradient1: tensor([-35.5739]);
# Gradient1: tensor([[-3.7051]]); Gradient1: tensor([-35.3623]);
#
# epoch: 39; loss: 8.846532821655273; weight: 0.9878950715065002; bias: 0.5039139986038208
# Gradient1: tensor([[-3.7051]]); Gradient1: tensor([-35.3623]);
# Gradient1: tensor([[-4.3532]]); Gradient1: tensor([-35.0789]);
#
# epoch: 40; loss: 8.857454299926758; weight: 0.9922482371330261; bias: 0.5389928817749023
# Gradient1: tensor([[-4.3532]]); Gradient1: tensor([-35.0789]);
# Gradient1: tensor([[-3.8292]]); Gradient1: tensor([-34.7242]);
#
# epoch: 41; loss: 8.874975204467773; weight: 0.9960774779319763; bias: 0.5737170577049255
# Gradient1: tensor([[-3.8292]]); Gradient1: tensor([-34.7242]);
# Gradient1: tensor([[-2.2732]]); Gradient1: tensor([-34.2990]);
#
# epoch: 42; loss: 8.894983291625977; weight: 0.9983506798744202; bias: 0.6080160737037659
# Gradient1: tensor([[-2.2732]]); Gradient1: tensor([-34.2990]);
# Gradient1: tensor([[-0.1010]]); Gradient1: tensor([-33.8046]);
#
# epoch: 43; loss: 8.913058280944824; weight: 0.9984516501426697; bias: 0.6418207287788391
# Gradient1: tensor([[-0.1010]]); Gradient1: tensor([-33.8046]);
# Gradient1: tensor([[2.1073]]); Gradient1: tensor([-33.2426]);
#
# epoch: 44; loss: 8.928768157958984; weight: 0.9963443875312805; bias: 0.6750633716583252
# Gradient1: tensor([[2.1073]]); Gradient1: tensor([-33.2426]);
# Gradient1: tensor([[3.7614]]); Gradient1: tensor([-32.6147]);
#
# epoch: 45; loss: 8.945945739746094; weight: 0.9925829768180847; bias: 0.7076780796051025
# Gradient1: tensor([[3.7614]]); Gradient1: tensor([-32.6147]);
# Gradient1: tensor([[4.4196]]); Gradient1: tensor([-31.9226]);
#
# epoch: 46; loss: 8.96872329711914; weight: 0.988163411617279; bias: 0.739600658416748
# Gradient1: tensor([[4.4196]]); Gradient1: tensor([-31.9226]);
# Gradient1: tensor([[3.9057]]); Gradient1: tensor([-31.1677]);
#
# epoch: 47; loss: 8.997234344482422; weight: 0.984257698059082; bias: 0.770768404006958
# Gradient1: tensor([[3.9057]]); Gradient1: tensor([-31.1677]);
# Gradient1: tensor([[2.3568]]); Gradient1: tensor([-30.3516]);
#
# epoch: 48; loss: 9.027298927307129; weight: 0.9819008708000183; bias: 0.8011199831962585
# Gradient1: tensor([[2.3568]]); Gradient1: tensor([-30.3516]);
# Gradient1: tensor([[0.1865]]); Gradient1: tensor([-29.4754]);
#
# epoch: 49; loss: 9.054401397705078; weight: 0.9817143678665161; bias: 0.8305953741073608
# Gradient1: tensor([[0.1865]]); Gradient1: tensor([-29.4754]);
# Gradient1: tensor([[-2.0258]]); Gradient1: tensor([-28.5403]);
#
# epoch: 50; loss: 9.077985763549805; weight: 0.9837401509284973; bias: 0.859135627746582
# Gradient1: tensor([[-2.0258]]); Gradient1: tensor([-28.5403]);
# Gradient1: tensor([[-3.6894]]); Gradient1: tensor([-27.5475]);

# %%
plt.plot(range(epochs), losses)
plt.ylabel('Loss')
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
x1 = np.array([X.min(),X.max()])
# ax + b
[w, b] = model.parameters()
y1 = w.item() * x1 + b.item()

plt.scatter(X.numpy(), y.numpy())
plt.plot(x1, y1,'r')
plt.ylabel('y')
plt.xlabel('x');
